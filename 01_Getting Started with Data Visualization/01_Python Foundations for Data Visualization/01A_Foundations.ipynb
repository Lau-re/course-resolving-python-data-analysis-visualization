# %% [markdown]
# # Python Foundations for Data Visualization

# %% [markdown]
# ## Create objects with data

# %% [markdown]
# ### Football Teams

# %%
football_teams = ['Real Madrid', 'Barcelona', 'Bayern Munich']

# %% [markdown]
# ### Champions Leagues

# %%
champions_leagues = [14, 5, 6]

# %% [markdown]
# <div class="alert alert-info">
#     The <b>function</b> processes data to give you the result you want.
#     <br><b>Libraries</b> store functions to give you results of a particular topic.
# </div>

# %%
tu ordenador , sesion de trabajo , kernel de python

# %% [markdown]
# ## Import matplotlib library
#
# > **Mat**hematical **Plot**ting **Lib**rary
#
# Matplotlib is a Python library that contains functions to create Data Visualizations

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Scatter plot (points)

# %%
reglas de sintaxis , buenas practicas de codigo

# %%
plt.scatter(x=football_teams, y=champions_leagues)

# %% [markdown]
# ### Bar plot

# %%
plt.bar(x=football_teams, height=champions_leagues)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Many others

# %% [markdown]
# https://matplotlib.org/stable/plot_types/index

# %% [markdown]
# ## Customize the plot

# %% [markdown]
# ### Change the size

# %%
plt.scatter(x=football_teams, y=champions_leagues, s=110)

# %% [markdown]
# ### Change the color

# %%
plt.scatter(x=football_teams, y=champions_leagues, s=110, c='grey')

# %% [markdown]
# ### Change the marker

# %% [markdown]
# https://matplotlib.org/stable/api/markers_api.html

# %%
plt.scatter(x=football_teams, y=champions_leagues, s=110, c='grey')

# %% [markdown]
# ### Change the border
